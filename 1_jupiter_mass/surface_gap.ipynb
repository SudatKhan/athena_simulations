# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
sys.path.insert(0, '/home/sudat/athena/vis/python')
import athena_read

# %%
'''Reading data from HDF5 files'''
data1 = athena_read.athdf('disk.out1.16532.athdf')
data2 = athena_read.athdf('disk.out3.16532.athdf')
density = data1.get('dens')[0]
r = data1.get('x1v')
phi = data1.get('x2v')

# %%
plt.plot(r, (np.average(density, axis=0)))
plt.ylabel(r'$\frac{\rho}{\rho_{0}}$')
plt.xlabel(r'$\frac{R}{R_{p}}$')
# Out:
# Text(0.5, 0, '$\\frac{R}{R_{p}}$')
